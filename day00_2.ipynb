# %% [markdown]
# <a href="https://colab.research.google.com/github/clappingmin/deeplearning/blob/master/day00_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 144579 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm


fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(5,5))
plt.plot([0,1], [0,1], label='한글테스트용')
plt.legend()
plt.show()

# %%
#인구증가율
population_inc = [0.3,-0.78,1.26,0.03,1.11,15.37,0.24,-0.24,-0.47,-0.77,-0.37]
population_inc = population_inc[:5]+population_inc[6:]

#노령인구비율
population_old = [12.27,14.44,11.87,18.75,17.52,14.27,16.37,19.78,19.51,12.65,14.74]
population_old = population_old[:5]+population_old[6:]
plt.plot(population_inc,population_old,'bo')
plt.xlabel('인구증가율')
plt.ylabel('노령인구비율')
plt.show()

# %%
#확인용
a=[1,2,3]
b=[4,5,6]

for i,j in list(zip(a,b)):
  print(i,j)
# Out:
# 1 4
# 2 5
# 3 6

# %%
#최소제곱법

x = [0.3,-0.78,1.26,0.03,1.11,15.37,0.24,-0.24,-0.47,-0.77,-0.37]
x = x[:5]+x[6:]

#노령인구비율
y = [12.27,14.44,11.87,18.75,17.52,9.29,16.37,19.78,19.51,12.65,14.74]
y = y[:5]+y[6:]

x_bar = sum (x) / len(x)
y_bar = sum (y) /len(y)

a = sum([(y-y_bar)*(x-x_bar) for y,x in list(zip(y,x))])
a = a/sum([ (i-x_bar)**2 for i in x])
#기울기 a = (x-x평균)(y-y평균)의 합 / (x-x평균)의 제곱의 합

b = y_bar - (a*x_bar)
#절편   b = y평균 - (x평균*a)

import numpy as np
line_x = np.arange(min(x),max(x),1)
line_y = a * line_x + b
plt.plot(line_x,line_y, 'r--')

plt.plot(x,y,'bo')
plt.show()

#원래값 - 구해진값
#y = a * x + b

# %%
import random
import tensorflow as tf
import numpy as np

#인구증가율
x = [0.3, -0.78, 1.26, 0.03, 1.11, 15.17, 0.24, -0.24, -0.47, -0.77, -0.37]
x = x[:5] + x[6:]
#고령인구비율
y = [12.27, 14.44, 11.87, 18.75, 17.52, 9.29, 16.37, 19.78, 19.51, 12.65, 14.74]
y = y[:5]+y[6:]

a = tf.Variable(random.random())
b = tf.Variable(random.random())

def compute_loss():
  y_pred = a * x + b
  loss = tf.reduce_mean((y-y_pred)**2)

  return loss

optimizer = tf.keras.optimizers.Adam(lr=0.07)

for i in range(2000):
  optimizer.minimize(compute_loss, var_list=[a,b])
  if i % 100 == 99:
    print("{} ,{} ,{}".format(i, a.numpy(), compute_loss().numpy()))
# Out:
# 99 ,0.0026859892532229424 ,83.9061279296875
# 199 ,-0.2978054881095886 ,26.337451934814453
# 299 ,-0.47063276171684265 ,11.089799880981445
# 399 ,-0.5496217012405396 ,8.41049575805664
# 499 ,-0.5782169699668884 ,8.104338645935059
# 599 ,-0.5864454507827759 ,8.081624984741211
# 699 ,-0.5883303880691528 ,8.080536842346191
# 799 ,-0.5886731743812561 ,8.0805025100708
# 899 ,-0.588721513748169 ,8.0805025100708
# 999 ,-0.5887265205383301 ,8.0805025100708
# 1099 ,-0.5887265205383301 ,8.0805025100708
# 1199 ,-0.5887264609336853 ,8.0805025100708
# 1299 ,-0.5887264609336853 ,8.0805025100708
# 1399 ,-0.5887264609336853 ,8.0805025100708
# 1499 ,-0.5887264609336853 ,8.0805025100708
# 1599 ,-0.5887264609336853 ,8.0805025100708
# 1699 ,-0.5887264609336853 ,8.080500602722168
# 1799 ,-0.5887264013290405 ,8.0805025100708
# 1899 ,-0.5887265801429749 ,8.080500602722168
# 1999 ,-0.588726818561554 ,8.080503463745117

# %%
import tensorflow as tf

#인구증가율
x = [0.3, -0.78, 1.26, 0.03, 1.11, 15.17, 0.24, -0.24, -0.47, -0.77, -0.37]
x = x[:5] + x[6:]
#고령인구비율
y = [12.27, 14.44, 11.87, 18.75, 17.52, 9.29, 16.37, 19.78, 19.51, 12.65, 14.74]
y = y[:5]+y[6:]

model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=6, activation='sigmoid',input_shape=(1,)),
    tf.keras.layers.Dense(units=1)
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 6)                 12
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 7
# ...
# Total params: 19
# Trainable params: 19
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.1),loss='mse')
history = model.fit(x,y,epochs=200)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 3ms/step - loss: 7.2204
# Epoch 2/200
# 1/1 [==============================] - 0s 1ms/step - loss: 7.2117
# Epoch 3/200
# 1/1 [==============================] - 0s 2ms/step - loss: 7.2030
# Epoch 4/200
# 1/1 [==============================] - 0s 1ms/step - loss: 7.1943
# Epoch 5/200
# 1/1 [==============================] - 0s 1ms/step - loss: 7.1857
# Epoch 6/200
# 1/1 [==============================] - 0s 1ms/step - loss: 7.1771
# Epoch 7/200
# 1/1 [==============================] - 0s 1ms/step - loss: 7.1686
# Epoch 8/200
# 1/1 [==============================] - 0s 1ms/step - loss: 7.1601
# Epoch 9/200
# 1/1 [==============================] - 0s 1ms/step - loss: 7.1515
# Epoch 10/200
# 1/1 [==============================] - 0s 1ms/step - loss: 7.1431
# Epoch 11/200
# 1/1 [==============================] - 0s 1ms/step - loss: 7.1346
# Epoch 12/200
# 1/1 [==============================] - 0s 2ms/step - loss: 7.1261
# ...

# %%
import matplotlib.pyplot as plt

line_x = np.arange(min(x),max(x),0.01)
line_y = model.predict(line_x)

plt.plot(line_x,line_y,'r--')
plt.plot(x,y,'bo')
plt.show()

# %%
import tensorflow as tf

data_path = tf.keras.utils.get_file("auto-mpg.data", "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")
data_path

import pandas as pd

column_names = ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'Modelyear', 'Origin']
raw_dataset = pd.read_csv(data_path, names= column_names, na_values="?", comment='\t', sep=" ", skipinitialspace=True)

dataset = raw_dataset.copy()
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  ...  Acceleration  Modelyear  Origin
# 393  27.0          4         140.0  ...          15.6         82       1
# 394  44.0          4          97.0  ...          24.6         82       2
# 395  32.0          4         135.0  ...          11.6         82       1
# 396  28.0          4         120.0  ...          18.6         82       1
# 397  31.0          4         119.0  ...          19.4         82       1
#
# [5 rows x 8 columns]

# %%
#결측치를 확인하세요
#결측치를 처리하세요
# Origin을 원핫코딩으로 처리

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MPG           398 non-null    float64
#  1   Cylinders     398 non-null    int64
#  2   Displacement  398 non-null    float64
#  3   Horsepower    392 non-null    float64
#  4   Weight        398 non-null    float64
#  5   Acceleration  398 non-null    float64
#  6   Modelyear     398 non-null    int64
#  7   Origin        398 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 25.0 KB

# %%
mean_Hor = dataset['Horsepower'].mean(axis=0)
dataset.fillna(mean_Hor,inplace = True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MPG           392 non-null    float64
#  1   Cylinders     392 non-null    int64
#  2   Displacement  392 non-null    float64
#  3   Horsepower    392 non-null    float64
#  4   Weight        392 non-null    float64
#  5   Acceleration  392 non-null    float64
#  6   Modelyear     392 non-null    int64
#  7   Origin        392 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 27.6 KB

# %%
dataset_one_hot_encoded = pd.get_dummies(dataset['Origin'])
dataset_one_hot_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1       392 non-null    uint8
#  1   2       392 non-null    uint8
#  2   3       392 non-null    uint8
# dtypes: uint8(3)
# memory usage: 4.2 KB

# %%
result = pd.concat([dataset, dataset_one_hot_encoded], axis=1)

# %%
result.rename(columns={1:'USA'},inplace=True)
result.rename(columns={2:'Europe'},inplace=True)
result.rename(columns={3:'Japan'},inplace=True)

# %%
del result['Origin']

# %%
result
# Out:
#       MPG  Cylinders  Displacement  Horsepower  ...  Modelyear  USA  Europe  Japan
# 0    18.0          8         307.0       130.0  ...         70    1       0      0
# 1    15.0          8         350.0       165.0  ...         70    1       0      0
# 2    18.0          8         318.0       150.0  ...         70    1       0      0
# 3    16.0          8         304.0       150.0  ...         70    1       0      0
# 4    17.0          8         302.0       140.0  ...         70    1       0      0
# ..    ...        ...           ...         ...  ...        ...  ...     ...    ...
# 393  27.0          4         140.0        86.0  ...         82    1       0      0
# 394  44.0          4          97.0        52.0  ...         82    0       1      0
# 395  32.0          4         135.0        84.0  ...         82    1       0      0
# 396  28.0          4         120.0        79.0  ...         82    1       0      0
# ...

# %%
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      0
# Weight          0
# Acceleration    0
# Modelyear       0
# Origin          0
# dtype: int64

# %%
dataset = dataset.dropna()

# %%
#데이터셋 훈련 세트 분할하기

train_dataset = result.sample(frac=0.8, random_state=0)
test_dataset = result.drop(train_dataset.index)
train_dataset

# from sklearn.model_selection as train_test_split
# Out:
#       MPG  Cylinders  Displacement  Horsepower  ...  Modelyear  USA  Europe  Japan
# 146  28.0          4          90.0        75.0  ...         74    1       0      0
# 282  22.3          4         140.0        88.0  ...         79    1       0      0
# 69   12.0          8         350.0       160.0  ...         72    1       0      0
# 378  38.0          4         105.0        63.0  ...         82    1       0      0
# 331  33.8          4          97.0        67.0  ...         80    0       0      1
# ..    ...        ...           ...         ...  ...        ...  ...     ...    ...
# 281  19.8          6         200.0        85.0  ...         79    1       0      0
# 229  16.0          8         400.0       180.0  ...         77    1       0      0
# 150  26.0          4         108.0        93.0  ...         74    0       0      1
# 145  32.0          4          83.0        61.0  ...         74    0       0      1
# ...

# %%
trans_status = train_dataset.describe()

# %%
import pandas as pd
d1 = {'col1':[1,2],'col2':[3,4]}
d2 = pd.DataFrame(data=d1)
d2
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
d3={'sum':[1,2],'avg':[3,4]}
d4 = pd.DataFrame(data = d3, index=['col1','col2'])
d4
# Out:
#       sum  avg
# col1    1    3
# col2    2    4

# %%
train_stats = train_dataset.describe()
train_stats = train_stats.transpose()

# %%
train_stats
# Out:
#               count         mean         std  ...     50%      75%     max
# MPG           314.0    23.310510    7.728652  ...    22.0    28.95    46.6
# Cylinders     314.0     5.477707    1.699788  ...     4.0     8.00     8.0
# Displacement  314.0   195.318471  104.331589  ...   151.0   265.75   455.0
# Horsepower    314.0   104.869427   38.096214  ...    94.5   128.00   225.0
# Weight        314.0  2990.251592  843.898596  ...  2822.5  3608.00  5140.0
# Acceleration  314.0    15.559236    2.789230  ...    15.5    17.20    24.8
# Modelyear     314.0    75.898089    3.675642  ...    76.0    79.00    82.0
# USA           314.0     0.624204    0.485101  ...     1.0     1.00     1.0
# Europe        314.0     0.178344    0.383413  ...     0.0     0.00     1.0
# Japan         314.0     0.197452    0.398712  ...     0.0     0.00     1.0
#
# [10 rows x 8 columns]

# %%
def norm(x):
  return (x-train_stats['mean'])/ train_stats['std']

train_dataset = norm(train_dataset)
train_dataset
# Out:
#           MPG  Cylinders  Displacement  ...       USA    Europe     Japan
# 146  0.606767  -0.869348     -1.009459  ...  0.774676 -0.465148 -0.495225
# 282 -0.130748  -0.869348     -0.530218  ...  0.774676 -0.465148 -0.495225
# 69  -1.463452   1.483887      1.482595  ...  0.774676 -0.465148 -0.495225
# 378  1.900654  -0.869348     -0.865687  ...  0.774676 -0.465148 -0.495225
# 331  1.357221  -0.869348     -0.942365  ... -1.286751 -0.465148  2.012852
# ..        ...        ...           ...  ...       ...       ...       ...
# 281 -0.454220   0.307270      0.044872  ...  0.774676 -0.465148 -0.495225
# 229 -0.945897   1.483887      1.961837  ...  0.774676 -0.465148 -0.495225
# 150  0.347990  -0.869348     -0.836932  ... -1.286751 -0.465148  2.012852
# 145  1.124322  -0.869348     -1.076553  ... -1.286751 -0.465148  2.012852
# 182  0.606767  -0.869348     -0.846517  ... -1.286751  2.143005 -0.495225
#
# [314 rows x 10 columns]

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
                          layers.Dense(64,activation="relu",input_shape=[len(train_dataset.keys())]),                          
                          layers.Dense(64,activation="relu"),
                          layers.Dense(1,activation="relu")
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 64)                704
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# ...
# Total params: 4,929
# Trainable params: 4,929
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.SGD(lr=0.01)
#회귀: loss:mse로 지표는 mae
model.compile(optimizer=optimizer, loss='mse',metrics=['mae','mse'])

#학습하기
validation_split=0.2
history = model.fit(train_dataset , train_labels, epochs=1000, validation_split=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-7ca098fca525> in <module>()
#       5 #학습하기
#       6 validation_split=0.2
# ----> 7 history = model.fit(train_dataset , train_labels, epochs=1000, validation_split=0.2)
#
# NameError: name 'train_labels' is not defined
